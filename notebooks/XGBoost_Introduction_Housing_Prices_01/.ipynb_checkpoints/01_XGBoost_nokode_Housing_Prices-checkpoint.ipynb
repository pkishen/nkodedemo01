# %% [markdown]
# ## Train and deploy model on Kubeflow in Notebooks
#
# This examples comes from a upstream fairing [example](https://github.com/kubeflow/fairing/tree/master/examples/prediction).
#
#
# Please check Kaggle competiton [
# House Prices: Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
# for details about the ML problem we want to resolve.
#
# This notebook introduces you to using Kubeflow Fairing to train and deploy a model to Kubeflow on Amazon EKS. This notebook demonstrate how to:
#
# * Train an XGBoost model in a local notebook,
# * Use Kubeflow Fairing to train an XGBoost model remotely on Kubeflow,
# * Use Kubeflow Fairing to deploy a trained model to Kubeflow,
# * Call the deployed endpoint for predictions.

# %% [markdown]
# ### Install python dependencies

# %%
# %%writefile requirements.txt
# pandas
# joblib
# numpy
# xgboost
# scikit-learn>=0.21.0
# seldon-core
# tornado>=6.0.3
# nc
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.18.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.90)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (0.23.2)
# Requirement already satisfied: seldon-core in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (6.0.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 1)) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.0->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: gunicorn<20.1.0,>=19.9.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (20.0.4)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (3.11.2)
# Requirement already satisfied: grpcio-opentracing<1.2.0,>=1.1.4 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.1.4)
# Requirement already satisfied: Flask<2.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (45.1.0)
# Requirement already satisfied: redis<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (3.5.3)
# Requirement already satisfied: jaeger-client<4.4.0,>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: jsonschema<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (2.22.0)
# Requirement already satisfied: opentracing<2.4.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: Flask-OpenTracing<1.2.0,>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: grpcio<2.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.32.0)
# Requirement already satisfied: prometheus-client<0.9.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: PyYAML<5.4 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (5.3)
# Requirement already satisfied: flatbuffers<2.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.12)
# Requirement already satisfied: Flask-cors<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (0.16.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (2.11.0)
# Requirement already satisfied: thrift in /usr/local/lib/python3.6/dist-packages (from jaeger-client<4.4.0,>=4.1.0->seldon-core->-r requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: threadloop<2,>=1 in /usr/local/lib/python3.6/dist-packages (from jaeger-client<4.4.0,>=4.1.0->seldon-core->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from jsonschema<4.0.0->seldon-core->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema<4.0.0->seldon-core->-r requirements.txt (line 6)) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema<4.0.0->seldon-core->-r requirements.txt (line 6)) (19.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 6)) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 6)) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 6)) (2.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->jsonschema<4.0.0->seldon-core->-r requirements.txt (line 6)) (2.1.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ### Develop your model

# %%
# %%writefile ~/nkodedemo01/nkode/train_model.py
import argparse
import logging
import joblib
import sys
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from xgboost import XGBRegressor

logging.basicConfig(format='%(message)s')
logging.getLogger().setLevel(logging.INFO)
# Out:
# Overwriting /home/jovyan/nkodedemo01/nkode/train_model.py

# %%
# %%writefile ~/nkodedemo01/nkode/train_model.py -a
# def read_input(file_name, test_size=0.25):
#     """Read input data and split it into train and test."""
#     data = pd.read_csv(file_name)
#     data.dropna(axis=0, subset=['SalePrice'], inplace=True)
#
#     y = data.SalePrice
#     X = data.drop(['SalePrice'], axis=1).select_dtypes(exclude=['object'])
#
#     train_X, test_X, train_y, test_y = train_test_split(X.values,
#                                                       y.values,
#                                                       test_size=test_size,
#                                                       shuffle=False)
#
#     imputer = SimpleImputer()
#     train_X = imputer.fit_transform(train_X)
#     test_X = imputer.transform(test_X)
#
#     return (train_X, train_y), (test_X, test_y)
#
# def train_model(train_X,
#                 train_y,
#                 test_X,
#                 test_y,
#                 n_estimators,
#                 learning_rate):
#     """Train the model using XGBRegressor."""
#     model = XGBRegressor(n_estimators=n_estimators, learning_rate=learning_rate)
#
#     model.fit(train_X,
#             train_y,
#             early_stopping_rounds=40,
#             eval_set=[(test_X, test_y)])
#
#     print("Best RMSE on eval: %.2f with %d rounds" %
#                (model.best_score,
#                 model.best_iteration+1))
#     return model
#
# def eval_model(model, test_X, test_y):
#     """Evaluate the model performance."""
#     predictions = model.predict(test_X)
#     logging.info("mean_absolute_error=%.2f", mean_absolute_error(predictions, test_y))
#
# def save_model(model, model_file):
#     """Save XGBoost model for serving."""
#     joblib.dump(model, model_file)
#     logging.info("Model export success: %s", model_file)
#
#
# class nkTrain(object):
#
#     def __init__(self):
#         self.train_input = "data/train.csv"
#         self.n_estimators = 50
#         self.learning_rate = 0.1
#         self.model_file = "trained_ames_model.dat"
#         self.model = None
#
#     def train(self):
#         (train_X, train_y), (test_X, test_y) = read_input(self.train_input)
#         model = train_model(train_X,
#                           train_y,
#                           test_X,
#                           test_y,
#                           self.n_estimators,
#                           self.learning_rate)
#
#         eval_model(model, test_X, test_y)
#         save_model(model, self.model_file)
#
#     def predict(self, X, feature_names=None):
#         """Predict using the model for given ndarray."""
#         if not self.model:
#             self.model = joblib.load(self.model_file)
#         # Do any preprocessing
#         prediction = self.model.predict(data=X)
#         # Do any postprocessing
#         return prediction
# Out:
# Appending to /home/jovyan/nkodedemo01/nkode/train_model.py

# %% [markdown]
# ### Train an XGBoost model in a notebook

# %%
model = nkTrain()
model.train()
# Out:
# [21:05:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:177514
# Will train until validation_0-rmse hasn't improved in 40 rounds.
# [1]	validation_0-rmse:161858
# [2]	validation_0-rmse:147237
# [3]	validation_0-rmse:134132
# [4]	validation_0-rmse:122224
# [5]	validation_0-rmse:111538
# [6]	validation_0-rmse:102142
# [7]	validation_0-rmse:93392.3
# [8]	validation_0-rmse:85824.6
# [9]	validation_0-rmse:79667.6
# [10]	validation_0-rmse:73463.4
# [11]	validation_0-rmse:68059.4
# [12]	validation_0-rmse:63350.5
# [13]	validation_0-rmse:59732.1
# [14]	validation_0-rmse:56260.7
# [15]	validation_0-rmse:53392.6
# [16]	validation_0-rmse:50770.8
# [17]	validation_0-rmse:48107.8
# [18]	validation_0-rmse:45923.9
# [19]	validation_0-rmse:44154.2
# [20]	validation_0-rmse:42488.1
# [21]	validation_0-rmse:41263.3
# [22]	validation_0-rmse:40212.8
# [23]	validation_0-rmse:39089.1
# [24]	validation_0-rmse:37691.1
# [25]	validation_0-rmse:36875.2
# [26]	validation_0-rmse:36276.2
# [27]	validation_0-rmse:35444.1
# [28]	validation_0-rmse:34831.5
# [29]	validation_0-rmse:34205.4
# [30]	validation_0-rmse:33831.9
# [31]	validation_0-rmse:33183.6
# [32]	validation_0-rmse:33019.4
# [33]	validation_0-rmse:32680
# [34]	validation_0-rmse:32438.5
# [35]	validation_0-rmse:32130.4
# [36]	validation_0-rmse:31644.2
# [37]	validation_0-rmse:31248.9
# [38]	validation_0-rmse:31059.8
# [39]	validation_0-rmse:30862.4
# [40]	validation_0-rmse:30754
# [41]	validation_0-rmse:30561.6
# [42]	validation_0-rmse:30416.9
# [43]	validation_0-rmse:30156.4
# [44]	validation_0-rmse:29852.9
# [45]	validation_0-rmse:29486.6
# [46]	validation_0-rmse:29158.8
# [47]	validation_0-rmse:29017
# [48]	validation_0-rmse:28973.9
# [49]	validation_0-rmse:28787.7
# mean_absolute_error=18173.15
# Best RMSE on eval: 28787.72 with 50 rounds
# Model export success: trained_ames_model.dat

# %% [markdown]
# ### Build Images and Train Remotely
#
# > This will build image and run the training to ensure it deploys correctly
# Make sure
# 1. you write your training files by uncommenting first line
# 2. Your training class or function is named nkTrain

# %%
# !sh ~/nkodedemo01/nkode/remote_train.sh
# Out:
# ~/nkodedemo01/notebooks/Tensor_Flow_Introduction_01/
# About to train job setup...
# The FunctionPreProcessor is optimized for using in a notebook or IPython environment. For it to work, the python version should be same for both local python and the python in the docker. Please look at alternatives like BasePreprocessor or FullNotebookPreprocessor.
# Using builder: <class 'kubeflow.fairing.builders.cluster.cluster.ClusterBuilder'>
# about to submit job
# Building the docker image.
# Building image using cluster builder.
# /usr/local/lib/python3.6/dist-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Creating docker context: /tmp/fairing_context_bgl6d0oq
# /usr/local/lib/python3.6/dist-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Not able to find aws credentials secret: aws-secret
# Waiting for fairing-builder-kw497-ss6gx to start...
# Waiting for fairing-builder-kw497-ss6gx to start...
# Waiting for fairing-builder-kw497-ss6gx to start...
# Pod started running True
# INFO[0000] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0001] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0002] Built cross stage deps: map[]
# INFO[0002] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0002] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0003] Executing 0 build triggers
# INFO[0003] Unpacking rootfs as cmd COPY /app//requirements.txt /app/ requires it.
# INFO[0036] WORKDIR /app/
# INFO[0036] cmd: workdir
# INFO[0036] Changed working directory to /app/
# INFO[0036] Creating directory /app/
# INFO[0036] Resolving 1 paths
# INFO[0036] Taking snapshot of files...
# INFO[0036] ENV FAIRING_RUNTIME 1
# INFO[0036] COPY /app//requirements.txt /app/
# INFO[0036] Resolving 1 paths
# INFO[0036] Taking snapshot of files...
# INFO[0036] RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# INFO[0036] Taking snapshot of full filesystem...
# INFO[0040] Resolving 27381 paths
# INFO[0043] cmd: /bin/sh
# INFO[0043] args: [-c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# INFO[0043] Running: [/bin/sh -c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/a2/21/e10d65222d19a2537e3eb0df306686a9eabd08b3c98dd120e43720bf802d/pandas-1.1.3-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
# Collecting joblib
#   Downloading https://files.pythonhosted.org/packages/fc/c9/f58220ac44a1592f79a343caba12f6837f9e0c04c196176a3d66338e1ea8/joblib-0.17.0-py3-none-any.whl (301kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.17.3)
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/35/cc/fd3d5fc6b6616a03385a0f6492cc77a253940d1026406ecc07597095e381/xgboost-1.2.1-py3-none-manylinux2010_x86_64.whl (148.9MB)
# Collecting scikit-learn>=0.21.0
#   Downloading https://files.pythonhosted.org/packages/5c/a1/273def87037a7fb010512bbc5901c31cfddfca8080bc63b42b26e3cc55b3/scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
# Collecting seldon-core
#   Downloading https://files.pythonhosted.org/packages/42/01/ef90f158a8d7555dc47c96cc5f38f177266de488e1f5f9045c5d559b6122/seldon_core-1.3.0-py3-none-any.whl (108kB)
# Collecting tornado>=6.0.3
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
# Collecting python-dateutil>=2.7.3
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
# Collecting pytz>=2017.2
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
# Collecting scipy
#   Downloading https://files.pythonhosted.org/packages/8a/14/d0475ceeaa047f3eae2dc7597c3d40228e1d5beee42c1730f3c96ffb5526/scipy-1.5.3-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Collecting requests<3.0.0
#   Downloading https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl (61kB)
# Collecting PyYAML<5.4
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
# Collecting gunicorn<20.1.0,>=19.9.0
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
# Collecting prometheus-client<0.9.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/3f/0e/554a265ffdc56e1494ef08e18f765b0cdec78797f510c58c45cf37abb4f4/prometheus_client-0.8.0-py2.py3-none-any.whl (53kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (41.4.0)
# Requirement already satisfied: grpcio<2.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.24.3)
# Collecting jaeger-client<4.4.0,>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/2b/75/17a937a61135671cebc175ab5c299dc0f7477042469482fd9a6f91262c68/jaeger-client-4.3.0.tar.gz (81kB)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (3.10.0)
# Collecting jsonschema<4.0.0
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
# Collecting Flask-OpenTracing<1.2.0,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/58/6c/6417701ba5ecc8854670c6db3207bcc3e5fbc96289a7cb18d5516d99a1c6/Flask-OpenTracing-1.1.0.tar.gz
# Collecting Flask<2.0.0
#   Downloading https://files.pythonhosted.org/packages/f2/28/2a03252dfb9ebf377f40fba6a7841b47083260bf8bd8e737b0c6952df83f/Flask-1.1.2-py2.py3-none-any.whl (94kB)
# Collecting redis<4.0.0
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
# Collecting opentracing<2.4.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/e4/a8/df5285f42cd07782409d0ae835785fae6e2a0f7e8b0036ea302f1422fd25/opentracing-2.3.0.tar.gz (48kB)
# Collecting grpcio-opentracing<1.2.0,>=1.1.4
#   Downloading https://files.pythonhosted.org/packages/db/82/2fcad380697c3dab25de76ee590bcab3eb9bbfb4add916044d7e83ec2b10/grpcio_opentracing-1.1.4-py3-none-any.whl
# Collecting Flask-cors<4.0.0
#   Downloading https://files.pythonhosted.org/packages/69/7f/d0aeaaafb5c3c76c8d2141dbe2d4f6dca5d6c31872d4e5349768c1958abc/Flask_Cors-3.0.9-py2.py3-none-any.whl
# Collecting flatbuffers<2.0.0
#   Downloading https://files.pythonhosted.org/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 6)) (2.6)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/56/aa/4ef5aa67a9a62505db124a5cb5262332d1d4153462eb8fd89c9fa41e5d92/urllib3-1.25.11-py2.py3-none-any.whl (127kB)
# Collecting chardet<4,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting certifi>=2017.4.17
#   Downloading https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl (156kB)
# Collecting threadloop<2,>=1
#   Downloading https://files.pythonhosted.org/packages/d3/1d/8398c1645b97dc008d3c658e04beda01ede3d90943d40c8d56863cf891bd/threadloop-1.0.2.tar.gz
# Collecting thrift
#   Downloading https://files.pythonhosted.org/packages/97/1e/3284d19d7be99305eda145b8aa46b0c33244e4a496ec66440dac19f8274d/thrift-0.13.0.tar.gz (59kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/6d/6d/f4bb28424bc677bce1210bc19f69a43efe823e294325606ead595211f93e/importlib_metadata-2.0.0-py2.py3-none-any.whl
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/14/df/479736ae1ef59842f512548bacefad1abed705e400212acba43f9b0fa556/attrs-20.2.0-py2.py3-none-any.whl (48kB)
# Collecting pyrsistent>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/4d/70/fd441df751ba8b620e03fd2d2d9ca902103119616f0f6cc42e6405035062/pyrsistent-0.17.3.tar.gz (106kB)
# Collecting click>=5.1
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Collecting Jinja2>=2.10.1
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (0.16.0)
# Collecting itsdangerous>=0.24
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/64/f2/0aa52375e14863b377bc9eb58fde6ec48e0a7f73fdf91c9876669559fe45/zipp-3.3.1-py3-none-any.whl
# Collecting MarkupSafe>=0.23
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Building wheels for collected packages: tornado, PyYAML, jaeger-client, Flask-OpenTracing, opentracing, threadloop, thrift, pyrsistent
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=429301 sha256=dbfb68c8b28896912c362e7385298db87c517065e067598bab53b3166522c473
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Building wheel for PyYAML (setup.py): started
#   Building wheel for PyYAML (setup.py): finished with status 'done'
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=45919 sha256=44e4c112ae72cfeabfe5911866e99b56402168cb2da1543f2835223fa15ad5d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
#   Building wheel for jaeger-client (setup.py): started
#   Building wheel for jaeger-client (setup.py): finished with status 'done'
#   Created wheel for jaeger-client: filename=jaeger_client-4.3.0-cp36-none-any.whl size=65466 sha256=84967bcc3feeac250ddee4c93491e2a9d156a8e173198c61ce8b6a9bf2c1efb3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/a4/46/e1/316c9ea87f46b9685c2f4258950a27bad1ae072c56224e4489
#   Building wheel for Flask-OpenTracing (setup.py): started
#   Building wheel for Flask-OpenTracing (setup.py): finished with status 'done'
#   Created wheel for Flask-OpenTracing: filename=Flask_OpenTracing-1.1.0-cp36-none-any.whl size=11454 sha256=993992f9e550d568d0790fe10b85607eb73602f259c05eb04344bc882fb86b96
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/7b/dc/25/3cf0b35c129232ee596c413f13d1d1f5a8e38c427266276dfd
#   Building wheel for opentracing (setup.py): started
#   Building wheel for opentracing (setup.py): finished with status 'done'
#   Created wheel for opentracing: filename=opentracing-2.3.0-cp36-none-any.whl size=51823 sha256=9e0fff10bc5ef7a8e2aefc344d3482fa91e5a7e97f7d610ad1444b7a40962a7e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/66/b5/60/322949294afda71a9558eb25a1e536d1191665ef71759646b7
#   Building wheel for threadloop (setup.py): started
#   Building wheel for threadloop (setup.py): finished with status 'done'
#   Created wheel for threadloop: filename=threadloop-1.0.2-cp36-none-any.whl size=4265 sha256=00d3fd1eaa27fe40f21c15efea9b9fd86de5b6c4a8b3641b88f610c286d29131
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/d7/7a/30/d212623a4cd34f6cce400f8122b1b7af740d3440c68023d51f
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.13.0-cp36-cp36m-linux_x86_64.whl size=346188 sha256=a708a1637676ca740217de0e103aed18984c824e35927c5e678646bd4a33aa46
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/02/a2/46/689ccfcf40155c23edc7cdbd9de488611c8fdf49ff34b1706e
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp36-cp36m-linux_x86_64.whl size=105631 sha256=6af119c68377219df4d473dac885beb00a22502166a04aaceb4012ee71838d26
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j51lxj4s/wheels/f0/b8/de/b593ad311be4eb458499d100db081e453576032272398b7ddc
# Successfully built tornado PyYAML jaeger-client Flask-OpenTracing opentracing threadloop thrift pyrsistent
# Installing collected packages: python-dateutil, pytz, pandas, joblib, scipy, xgboost, threadpoolctl, scikit-learn, urllib3, chardet, certifi, requests, PyYAML, gunicorn, prometheus-client, tornado, threadloop, thrift, opentracing, jaeger-client, zipp, importlib-metadata, attrs, pyrsistent, jsonschema, click, MarkupSafe, Jinja2, itsdangerous, Flask, Flask-OpenTracing, redis, grpcio-opentracing, Flask-cors, flatbuffers, seldon-core
# Successfully installed Flask-1.1.2 Flask-OpenTracing-1.1.0 Flask-cors-3.0.9 Jinja2-2.11.2 MarkupSafe-1.1.1 PyYAML-5.3.1 attrs-20.2.0 certifi-2020.6.20 chardet-3.0.4 click-7.1.2 flatbuffers-1.12 grpcio-opentracing-1.1.4 gunicorn-20.0.4 importlib-metadata-2.0.0 itsdangerous-1.1.0 jaeger-client-4.3.0 joblib-0.17.0 jsonschema-3.2.0 opentracing-2.3.0 pandas-1.1.3 prometheus-client-0.8.0 pyrsistent-0.17.3 python-dateutil-2.8.1 pytz-2020.1 redis-3.5.3 requests-2.24.0 scikit-learn-0.23.2 scipy-1.5.3 seldon-core-1.3.0 threadloop-1.0.2 threadpoolctl-2.1.0 thrift-0.13.0 tornado-6.0.4 urllib3-1.25.11 xgboost-1.2.1 zipp-3.3.1
# WARNING: You are using pip version 19.3.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0068] Taking snapshot of full filesystem...
# INFO[0071] Resolving 35659 paths
# INFO[0087] COPY /app/ /app/
# INFO[0087] Resolving 13 paths
# INFO[0087] Taking snapshot of files...
# Not able to find aws credentials secret: aws-secret
# The job fairing-job-mmgnh launched.
# Waiting for fairing-job-mmgnh-89zpn to start...
# Waiting for fairing-job-mmgnh-89zpn to start...
# Waiting for fairing-job-mmgnh-89zpn to start...
# Pod started running True
# [0]	validation_0-rmse:177565.34375
# Will train until validation_0-rmse hasn't improved in 40 rounds.
# [1]	validation_0-rmse:161967.20312
# [2]	validation_0-rmse:148001.89062
# [3]	validation_0-rmse:135010.17188
# [4]	validation_0-rmse:123514.68750
# [5]	validation_0-rmse:113210.39062
# [6]	validation_0-rmse:103914.61719
# [7]	validation_0-rmse:95352.96094
# [8]	validation_0-rmse:87878.77344
# [9]	validation_0-rmse:81683.14062
# [10]	validation_0-rmse:75828.78906
# [11]	validation_0-rmse:70085.50000
# [12]	validation_0-rmse:65076.06641
# [13]	validation_0-rmse:60899.83203
# [14]	validation_0-rmse:57354.22266
# [15]	validation_0-rmse:54106.52734
# [16]	validation_0-rmse:51402.42578
# [17]	validation_0-rmse:48774.04688
# [18]	validation_0-rmse:46360.19141
# [19]	validation_0-rmse:44304.82031
# [20]	validation_0-rmse:42618.65625
# [21]	validation_0-rmse:41219.88672
# [22]	validation_0-rmse:39885.14453
# [23]	validation_0-rmse:38977.95703
# [24]	validation_0-rmse:37856.47656
# [25]	validation_0-rmse:36739.78125
# [26]	validation_0-rmse:35847.46094
# [27]	validation_0-rmse:35350.00781
# [28]	validation_0-rmse:34857.17578
# [29]	validation_0-rmse:34342.78516
# [30]	validation_0-rmse:33752.83594
# [31]	validation_0-rmse:33613.74609
# [32]	validation_0-rmse:33468.86328
# [33]	validation_0-rmse:33188.18359
# [34]	validation_0-rmse:32825.68750
# [35]	validation_0-rmse:32538.23242
# [36]	validation_0-rmse:32235.01562
# [37]	validation_0-rmse:31968.84180
# [38]	validation_0-rmse:31724.04492
# [39]	validation_0-rmse:31474.02539
# [40]	validation_0-rmse:31259.08008
# [41]	validation_0-rmse:31034.54492
# [42]	validation_0-rmse:30885.66406
# [43]	validation_0-rmse:30737.64844
# [44]	validation_0-rmse:30562.84180
# [45]	validation_0-rmse:30434.94922
# [46]	validation_0-rmse:30314.07617
# [47]	validation_0-rmse:30231.97070
# [48]	validation_0-rmse:30100.18945
# [49]	validation_0-rmse:29988.56445
# mean_absolute_error=17379.71
# Model export success: trained_ames_model.dat
# Best RMSE on eval: 29988.56 with 50 rounds
# Cleaning up job fairing-job-mmgnh...

# %% [markdown]
# ### Deploy the trained model to Kubeflow for predictions
#
# Import the `PredictionEndpoint` and use the configured backend class. Kubeflow Fairing packages the `HousingServe` class, the trained model, and the prediction endpoint's software prerequisites as a Docker image. Then Kubeflow Fairing deploys and runs the prediction endpoint on Kubeflow.

# %%
# !sh ~/nkodedemo01/nkode/remote_deploy.sh
# Out:
# ~/nkodedemo01/notebooks/Tensor_Flow_Introduction_01/
# About to deploy to end point...
# The FunctionPreProcessor is optimized for using in a notebook or IPython environment. For it to work, the python version should be same for both local python and the python in the docker. Please look at alternatives like BasePreprocessor or FullNotebookPreprocessor.
# Using builder: <class 'kubeflow.fairing.builders.cluster.cluster.ClusterBuilder'>
# Building the docker image.
# Building image using cluster builder.
# /usr/local/lib/python3.6/dist-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Creating docker context: /tmp/fairing_context_ox5s1x1u
# /usr/local/lib/python3.6/dist-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Not able to find aws credentials secret: aws-secret
# Waiting for fairing-builder-nlz5b-ff22m to start...
# Waiting for fairing-builder-nlz5b-ff22m to start...
# Waiting for fairing-builder-nlz5b-ff22m to start...
# Pod started running True
# INFO[0000] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0001] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0002] Built cross stage deps: map[]
# INFO[0002] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0002] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0003] Executing 0 build triggers
# INFO[0003] Unpacking rootfs as cmd COPY /app//requirements.txt /app/ requires it.
# INFO[0038] WORKDIR /app/
# INFO[0038] cmd: workdir
# INFO[0038] Changed working directory to /app/
# INFO[0038] Creating directory /app/
# INFO[0038] Resolving 1 paths
# INFO[0038] Taking snapshot of files...
# INFO[0039] ENV FAIRING_RUNTIME 1
# INFO[0039] COPY /app//requirements.txt /app/
# INFO[0039] Resolving 1 paths
# INFO[0039] Taking snapshot of files...
# INFO[0039] RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# INFO[0039] Taking snapshot of full filesystem...
# INFO[0043] Resolving 27381 paths
# INFO[0046] cmd: /bin/sh
# INFO[0046] args: [-c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# INFO[0046] Running: [/bin/sh -c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/a2/21/e10d65222d19a2537e3eb0df306686a9eabd08b3c98dd120e43720bf802d/pandas-1.1.3-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
# Collecting joblib
#   Downloading https://files.pythonhosted.org/packages/fc/c9/f58220ac44a1592f79a343caba12f6837f9e0c04c196176a3d66338e1ea8/joblib-0.17.0-py3-none-any.whl (301kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.17.3)
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/35/cc/fd3d5fc6b6616a03385a0f6492cc77a253940d1026406ecc07597095e381/xgboost-1.2.1-py3-none-manylinux2010_x86_64.whl (148.9MB)
# Collecting scikit-learn>=0.21.0
#   Downloading https://files.pythonhosted.org/packages/5c/a1/273def87037a7fb010512bbc5901c31cfddfca8080bc63b42b26e3cc55b3/scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
# Collecting seldon-core
#   Downloading https://files.pythonhosted.org/packages/42/01/ef90f158a8d7555dc47c96cc5f38f177266de488e1f5f9045c5d559b6122/seldon_core-1.3.0-py3-none-any.whl (108kB)
# Collecting tornado>=6.0.3
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
# Collecting python-dateutil>=2.7.3
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
# Collecting pytz>=2017.2
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
# Collecting scipy
#   Downloading https://files.pythonhosted.org/packages/8a/14/d0475ceeaa047f3eae2dc7597c3d40228e1d5beee42c1730f3c96ffb5526/scipy-1.5.3-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Collecting prometheus-client<0.9.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/3f/0e/554a265ffdc56e1494ef08e18f765b0cdec78797f510c58c45cf37abb4f4/prometheus_client-0.8.0-py2.py3-none-any.whl (53kB)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (3.10.0)
# Collecting Flask-OpenTracing<1.2.0,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/58/6c/6417701ba5ecc8854670c6db3207bcc3e5fbc96289a7cb18d5516d99a1c6/Flask-OpenTracing-1.1.0.tar.gz
# Collecting grpcio-opentracing<1.2.0,>=1.1.4
#   Downloading https://files.pythonhosted.org/packages/db/82/2fcad380697c3dab25de76ee590bcab3eb9bbfb4add916044d7e83ec2b10/grpcio_opentracing-1.1.4-py3-none-any.whl
# Requirement already satisfied: grpcio<2.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (1.24.3)
# Collecting redis<4.0.0
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
# Collecting PyYAML<5.4
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
# Collecting flatbuffers<2.0.0
#   Downloading https://files.pythonhosted.org/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl
# Collecting opentracing<2.4.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/e4/a8/df5285f42cd07782409d0ae835785fae6e2a0f7e8b0036ea302f1422fd25/opentracing-2.3.0.tar.gz (48kB)
# Collecting gunicorn<20.1.0,>=19.9.0
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 6)) (41.4.0)
# Collecting Flask<2.0.0
#   Downloading https://files.pythonhosted.org/packages/f2/28/2a03252dfb9ebf377f40fba6a7841b47083260bf8bd8e737b0c6952df83f/Flask-1.1.2-py2.py3-none-any.whl (94kB)
# Collecting requests<3.0.0
#   Downloading https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl (61kB)
# Collecting jsonschema<4.0.0
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
# Collecting Flask-cors<4.0.0
#   Downloading https://files.pythonhosted.org/packages/69/7f/d0aeaaafb5c3c76c8d2141dbe2d4f6dca5d6c31872d4e5349768c1958abc/Flask_Cors-3.0.9-py2.py3-none-any.whl
# Collecting jaeger-client<4.4.0,>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/2b/75/17a937a61135671cebc175ab5c299dc0f7477042469482fd9a6f91262c68/jaeger-client-4.3.0.tar.gz (81kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.11.0)
# Collecting Jinja2>=2.10.1
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
# Collecting click>=5.1
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 6)) (0.16.0)
# Collecting itsdangerous>=0.24
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting certifi>=2017.4.17
#   Downloading https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl (156kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/56/aa/4ef5aa67a9a62505db124a5cb5262332d1d4153462eb8fd89c9fa41e5d92/urllib3-1.25.11-py2.py3-none-any.whl (127kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 6)) (2.6)
# Collecting chardet<4,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/6d/6d/f4bb28424bc677bce1210bc19f69a43efe823e294325606ead595211f93e/importlib_metadata-2.0.0-py2.py3-none-any.whl
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/14/df/479736ae1ef59842f512548bacefad1abed705e400212acba43f9b0fa556/attrs-20.2.0-py2.py3-none-any.whl (48kB)
# Collecting pyrsistent>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/4d/70/fd441df751ba8b620e03fd2d2d9ca902103119616f0f6cc42e6405035062/pyrsistent-0.17.3.tar.gz (106kB)
# Collecting threadloop<2,>=1
#   Downloading https://files.pythonhosted.org/packages/d3/1d/8398c1645b97dc008d3c658e04beda01ede3d90943d40c8d56863cf891bd/threadloop-1.0.2.tar.gz
# Collecting thrift
#   Downloading https://files.pythonhosted.org/packages/97/1e/3284d19d7be99305eda145b8aa46b0c33244e4a496ec66440dac19f8274d/thrift-0.13.0.tar.gz (59kB)
# Collecting MarkupSafe>=0.23
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/64/f2/0aa52375e14863b377bc9eb58fde6ec48e0a7f73fdf91c9876669559fe45/zipp-3.3.1-py3-none-any.whl
# Building wheels for collected packages: tornado, Flask-OpenTracing, PyYAML, opentracing, jaeger-client, pyrsistent, threadloop, thrift
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=429299 sha256=4f69e3c10cbdeadae814ef068ebfd0c2b6d5e9d66d78d04a549a2ead65e2735c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Building wheel for Flask-OpenTracing (setup.py): started
#   Building wheel for Flask-OpenTracing (setup.py): finished with status 'done'
#   Created wheel for Flask-OpenTracing: filename=Flask_OpenTracing-1.1.0-cp36-none-any.whl size=11454 sha256=8894dfc0ef1522ab62c84172affbdd06eaa86850810a8d8df87a109cd05e73bb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/7b/dc/25/3cf0b35c129232ee596c413f13d1d1f5a8e38c427266276dfd
#   Building wheel for PyYAML (setup.py): started
#   Building wheel for PyYAML (setup.py): finished with status 'done'
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=45919 sha256=b985a07acdbb87fd309c0b8259aa299c9662e8fb0469fa44c3c56b6c12ccf3ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
#   Building wheel for opentracing (setup.py): started
#   Building wheel for opentracing (setup.py): finished with status 'done'
#   Created wheel for opentracing: filename=opentracing-2.3.0-cp36-none-any.whl size=51823 sha256=3f0de1b1298af510ef5f66912c2b7e3b91165e547262cbf288fa0e6d9de92727
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/66/b5/60/322949294afda71a9558eb25a1e536d1191665ef71759646b7
#   Building wheel for jaeger-client (setup.py): started
#   Building wheel for jaeger-client (setup.py): finished with status 'done'
#   Created wheel for jaeger-client: filename=jaeger_client-4.3.0-cp36-none-any.whl size=65466 sha256=d9734a446d7ffdbf2ef4ec22094a2dca58f8fdca052fa9e0bdbbe0fd448b9f11
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/a4/46/e1/316c9ea87f46b9685c2f4258950a27bad1ae072c56224e4489
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp36-cp36m-linux_x86_64.whl size=105632 sha256=1af7625aa4b5568355d79952314e3a7ad8fc2c70d764432668d1f202a62316c9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/f0/b8/de/b593ad311be4eb458499d100db081e453576032272398b7ddc
#   Building wheel for threadloop (setup.py): started
#   Building wheel for threadloop (setup.py): finished with status 'done'
#   Created wheel for threadloop: filename=threadloop-1.0.2-cp36-none-any.whl size=4265 sha256=28c832a85a324241c74d4359b9d1e9bbe93ea23c5ac45c9a757bfb7a25bae3a0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/d7/7a/30/d212623a4cd34f6cce400f8122b1b7af740d3440c68023d51f
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.13.0-cp36-cp36m-linux_x86_64.whl size=346201 sha256=8920508978d45a582a7a0cd481056281f9d82f2ceed3c0ce7a605d0f9050d24d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58u8buqw/wheels/02/a2/46/689ccfcf40155c23edc7cdbd9de488611c8fdf49ff34b1706e
# Successfully built tornado Flask-OpenTracing PyYAML opentracing jaeger-client pyrsistent threadloop thrift
# Installing collected packages: python-dateutil, pytz, pandas, joblib, scipy, xgboost, threadpoolctl, scikit-learn, prometheus-client, MarkupSafe, Jinja2, click, itsdangerous, Flask, opentracing, Flask-OpenTracing, grpcio-opentracing, redis, PyYAML, flatbuffers, gunicorn, certifi, urllib3, chardet, requests, zipp, importlib-metadata, attrs, pyrsistent, jsonschema, Flask-cors, tornado, threadloop, thrift, jaeger-client, seldon-core
# Successfully installed Flask-1.1.2 Flask-OpenTracing-1.1.0 Flask-cors-3.0.9 Jinja2-2.11.2 MarkupSafe-1.1.1 PyYAML-5.3.1 attrs-20.2.0 certifi-2020.6.20 chardet-3.0.4 click-7.1.2 flatbuffers-1.12 grpcio-opentracing-1.1.4 gunicorn-20.0.4 importlib-metadata-2.0.0 itsdangerous-1.1.0 jaeger-client-4.3.0 joblib-0.17.0 jsonschema-3.2.0 opentracing-2.3.0 pandas-1.1.3 prometheus-client-0.8.0 pyrsistent-0.17.3 python-dateutil-2.8.1 pytz-2020.1 redis-3.5.3 requests-2.24.0 scikit-learn-0.23.2 scipy-1.5.3 seldon-core-1.3.0 threadloop-1.0.2 threadpoolctl-2.1.0 thrift-0.13.0 tornado-6.0.4 urllib3-1.25.11 xgboost-1.2.1 zipp-3.3.1
# WARNING: You are using pip version 19.3.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0071] Taking snapshot of full filesystem...
# INFO[0074] Resolving 35659 paths
# INFO[0090] COPY /app/ /app/
# INFO[0090] Resolving 13 paths
# INFO[0090] Taking snapshot of files...
# Deploying the endpoint.
# Cluster endpoint: http://fairing-service-8fv5z.eksworkshop.svc.cluster.local:5000/predict
# Prediction endpoint: http://fairing-service-8fv5z.eksworkshop.svc.cluster.local:5000/predict

# %% [markdown]
# ### Call the prediction endpoint
# Create a test dataset, then call the endpoint on Kubeflow for predictions.

# %%
# Wait service a while to be ready and replace `<endpoint>` with the output from last step.
# Here's an example !nc -vz fairing-service-srwh2.anonymous.svc.cluster.local 5000

# !nc -vz http://fairing-service-8fv5z.eksworkshop.svc.cluster.local 5000
# Out:
# /bin/sh: 1: nc: not found

# %%
# Get sample data and query endpoint
(train_X, train_y), (test_X, test_y) = read_input("ames_dataset/train.csv")

# PR https://github.com/kubeflow/fairing/pull/376
# Add `:5000/predict` to mitigate the issue.
endpoint.url='http://fairing-service-n8qv2.anonymous.svc.cluster.local:5000/predict'

endpoint.predict_nparray(test_X)

# %% [markdown]
# ### Clean up the prediction endpoint
# Delete the prediction endpoint created by this notebook.

# %%
endpoint.delete()

# %% [markdown]
# ### Clean up S3 bucket and ECR Repository
# Delete S3 bucket and ECR Repository that was created for this exercise

# %%
# !aws s3 rb s3://$S3_BUCKET --force
# !aws ecr delete-repository --repository-name fairing-job --region $AWS_REGION --force
