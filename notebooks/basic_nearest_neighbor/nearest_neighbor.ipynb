# %% [markdown]
# # Nearest Neighbor Example
#
# A nearest neighbor learning algorithm example using TensorFlow library.
# This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
#
# - Author: Aymeric Damien
# - Project: https://github.com/aymericdamien/TensorFlow-Examples/

# %%
# %%writefile requirements.txt
#
# tensorflow==1.15.2
# numpy
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# %%writefile train_model.py

import numpy as np
import tensorflow as tf

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Overwriting train_model.py

# %%
# %%writefile train_model.py -a
#
# # In this example, we limit mnist data
# Xtr, Ytr = mnist.train.next_batch(5000) #5000 for training (nn candidates)
# Xte, Yte = mnist.test.next_batch(200) #200 for testing
#
# # tf Graph Input
# xtr = tf.placeholder("float", [None, 784])
# xte = tf.placeholder("float", [784])
#
# # Nearest Neighbor calculation using L1 Distance
# # Calculate L1 Distance
# distance = tf.reduce_sum(tf.abs(tf.add(xtr, tf.negative(xte))), reduction_indices=1)
# # Prediction: Get min distance index (Nearest neighbor)
# pred = tf.argmin(distance, 0)
#
# accuracy = 0.
#
# # Initialize the variables (i.e. assign their default value)
# init = tf.global_variables_initializer()
# Out:
# Appending to train_model.py

# %%
# %%writefile train_model.py -a
#
# # Start training
# with tf.Session() as sess:
#     sess.run(init)
#
#     # loop over test data
#     for i in range(len(Xte)):
#         # Get nearest neighbor
#         nn_index = sess.run(pred, feed_dict={xtr: Xtr, xte: Xte[i, :]})
#         # Get nearest neighbor class label and compare it to its true label
#         print ("Test", i, "Prediction:", np.argmax(Ytr[nn_index]), \
#             "True Class:", np.argmax(Yte[i]))
#         # Calculate accuracy
#         if np.argmax(Ytr[nn_index]) == np.argmax(Yte[i]):
#             accuracy += 1./len(Xte)
#     print ("Done!")
#     print ("Accuracy:", accuracy)
# Out:
# Appending to train_model.py

# %%
# !nkode create:image -d "/tmp/data" -e "train_model.py"
# Out:
# hello auto from ./src/commands/hello.js
# sh /usr/lib/node_modules/nkode/scripts/remoteTrain/remote_train.sh  auto /tmp/data tensorflow/tensorflow:1.15.0-py3  train_model.py
# auto /tmp/data tensorflow/tensorflow:1.15.0-py3 train_model.py
# WARNING:tensorflow:From remote_train_currentrun.py:21: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From remote_train_currentrun.py:28: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From remote_train_currentrun.py:40: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From remote_train_currentrun.py:43: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-10-23 02:35:31.341963: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-10-23 02:35:31.362076: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2500000000 Hz
# 2020-10-23 02:35:31.362250: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x60a7fe0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 02:35:31.362266: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# [I 201023 02:35:33 utils:320] IMDS ENDPOINT: http://169.254.169.254/
# [W 201023 02:35:34 tasks:62] Using builder: <class 'kubeflow.fairing.builders.cluster.cluster.ClusterBuilder'>
# [I 201023 02:35:34 tasks:66] Building the docker image.
# [I 201023 02:35:34 cluster:46] Building image using cluster builder.
# [I 201023 02:35:34 base:107] Creating docker context: /tmp/fairing_context_jl_ozd9m
# [W 201023 02:35:34 aws:70] Not able to find aws credentials secret: aws-secret
# [W 201023 02:35:34 manager:298] Waiting for fairing-builder-w4w5z-wldhm to start...
# [W 201023 02:35:34 manager:298] Waiting for fairing-builder-w4w5z-wldhm to start...
# [W 201023 02:35:34 manager:298] Waiting for fairing-builder-w4w5z-wldhm to start...
# [I 201023 02:35:36 manager:304] Pod started running True
# Namespace(baseImage='tensorflow/tensorflow:1.15.0-py3', dataDir='/tmp/data', entryPoint='train_model.py', method='auto')
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Test 151 Prediction: 0 True Class: 0
# Test 152 Prediction: 6 True Class: 8
# Test 153 Prediction: 5 True Class: 5
# Test 154 Prediction: 7 True Class: 7
# Test 155 Prediction: 4 True Class: 4
# Test 156 Prediction: 3 True Class: 3
# Test 157 Prediction: 5 True Class: 5
# Test 158 Prediction: 4 True Class: 4
# Test 159 Prediction: 4 True Class: 4
# Test 160 Prediction: 3 True Class: 3
# Test 161 Prediction: 8 True Class: 8
# Test 162 Prediction: 5 True Class: 5
# Test 163 Prediction: 5 True Class: 5
# Test 164 Prediction: 6 True Class: 6
# Test 165 Prediction: 9 True Class: 9
# Test 166 Prediction: 6 True Class: 6
# Test 167 Prediction: 1 True Class: 1
# Test 168 Prediction: 1 True Class: 1
# Test 169 Prediction: 1 True Class: 2
# Test 170 Prediction: 0 True Class: 0
# Test 171 Prediction: 1 True Class: 1
# Test 172 Prediction: 0 True Class: 0
# Test 173 Prediction: 7 True Class: 7
# Test 174 Prediction: 5 True Class: 5
# Test 175 Prediction: 3 True Class: 3
# Test 176 Prediction: 7 True Class: 7
# Test 177 Prediction: 7 True Class: 8
# Test 178 Prediction: 4 True Class: 8
# Test 179 Prediction: 0 True Class: 0
# Test 180 Prediction: 9 True Class: 9
# Test 181 Prediction: 5 True Class: 5
# Test 182 Prediction: 0 True Class: 0
# Test 183 Prediction: 2 True Class: 2
# Test 184 Prediction: 8 True Class: 8
# Test 185 Prediction: 7 True Class: 7
# Test 186 Prediction: 6 True Class: 6
# Test 187 Prediction: 0 True Class: 0
# Test 188 Prediction: 7 True Class: 9
# Test 189 Prediction: 6 True Class: 6
# Test 190 Prediction: 7 True Class: 7
# Test 191 Prediction: 2 True Class: 2
# Test 192 Prediction: 4 True Class: 4
# Test 193 Prediction: 0 True Class: 0
# Test 194 Prediction: 3 True Class: 3
# Test 195 Prediction: 0 True Class: 0
# Test 196 Prediction: 1 True Class: 1
# Test 197 Prediction: 0 True Class: 0
# Test 198 Prediction: 8 True Class: 8
# Test 199 Prediction: 7 True Class: 7
# Done!
# Accuracy: 0.9050000000000007
# About to train job setup...
# about to submit job
# INFO[0000] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0001] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0001] Built cross stage deps: map[]
# INFO[0001] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0002] Retrieving image manifest tensorflow/tensorflow:1.15.0-py3
# INFO[0002] Executing 0 build triggers
# INFO[0002] Unpacking rootfs as cmd COPY /app//requirements.txt /app/ requires it.
# INFO[0036] WORKDIR /app/[W 201023 02:37:09 aws:70] Not able to find aws credentials secret: aws-secret
# [W 201023 02:37:09 job:101] The job fairing-job-zfskj launched.
# [W 201023 02:37:09 manager:298] Waiting for fairing-job-zfskj-gqm9c to start...
# [W 201023 02:37:09 manager:298] Waiting for fairing-job-zfskj-gqm9c to start...
# [W 201023 02:37:09 manager:298] Waiting for fairing-job-zfskj-gqm9c to start...
# [I 201023 02:37:21 manager:304] Pod started running True
#
# INFO[0036] cmd: workdir
# INFO[0036] Changed working directory to /app/
# INFO[0036] Creating directory /app/
# INFO[0036] Resolving 1 paths
# INFO[0036] Taking snapshot of files...
# INFO[0036] ENV FAIRING_RUNTIME 1
# INFO[0036] COPY /app//requirements.txt /app/
# INFO[0036] Resolving 1 paths
# INFO[0036] Taking snapshot of files...
# INFO[0036] RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# INFO[0036] Taking snapshot of full filesystem...
# INFO[0040] Resolving 27381 paths
# INFO[0044] cmd: /bin/sh
# INFO[0044] args: [-c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# INFO[0044] Running: [/bin/sh -c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# Collecting tensorflow==1.15.2
#   Downloading https://files.pythonhosted.org/packages/9a/d9/fd234c7bf68638423fb8e7f44af7fcfce3bcaf416b51e6d902391e47ec43/tensorflow-1.15.2-cp36-cp36m-manylinux2010_x86_64.whl (110.5MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/lib/python3/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.11.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.11.2)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.15.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (3.10.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/lib/python3/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (0.30.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r requirements.txt (line 2)) (0.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r requirements.txt (line 2)) (41.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2->-r requirements.txt (line 2)) (2.10.0)
# Installing collected packages: tensorflow
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# Successfully installed tensorflow-1.15.2
# WARNING: You are using pip version 19.3.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0055] Taking snapshot of full filesystem...
# INFO[0058] Resolving 27123 paths
# INFO[0071] COPY /app/ /app/
# INFO[0071] Resolving 6 paths
# INFO[0071] Taking snapshot of files...
# WARNING:tensorflow:From /app/train_model.py:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /app/train_model.py:14: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /app/train_model.py:26: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /app/train_model.py:29: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-10-23 02:37:26.428230: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-10-23 02:37:26.436098: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2500000000 Hz
# 2020-10-23 02:37:26.436433: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5550cd0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 02:37:26.436454: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version[W 201023 02:37:29 job:173] Cleaning up job fairing-job-zfskj...
#
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Test 0 Prediction: 6 True Class: 6
# Test 1 Prediction: 8 True Class: 8
# Test 2 Prediction: 2 True Class: 2
# Test 3 Prediction: 2 True Class: 2
# Test 4 Prediction: 9 True Class: 8
# Test 5 Prediction: 6 True Class: 6
# Test 6 Prediction: 6 True Class: 6
# Test 7 Prediction: 8 True Class: 8
# Test 8 Prediction: 6 True Class: 6
# Test 9 Prediction: 4 True Class: 4
# Test 10 Prediction: 5 True Class: 5
# Test 11 Prediction: 7 True Class: 7
# Test 12 Prediction: 0 True Class: 0
# Test 13 Prediction: 9 True Class: 9
# Test 14 Prediction: 8 True Class: 8
# Test 15 Prediction: 1 True Class: 1
# Test 16 Prediction: 0 True Class: 0
# Test 17 Prediction: 9 True Class: 9
# Test 18 Prediction: 0 True Class: 0
# Test 19 Prediction: 1 True Class: 1
# Test 20 Prediction: 6 True Class: 6
# Test 21 Prediction: 8 True Class: 8
# Test 22 Prediction: 2 True Class: 2
# Test 23 Prediction: 4 True Class: 4
# Test 24 Prediction: 2 True Class: 2
# Test 25 Prediction: 0 True Class: 0
# Test 26 Prediction: 7 True Class: 7
# Test 27 Prediction: 6 True Class: 6
# Test 28 Prediction: 9 True Class: 9
# Test 29 Prediction: 9 True Class: 9
# Test 30 Prediction: 7 True Class: 7
# Test 31 Prediction: 1 True Class: 1
# Test 32 Prediction: 3 True Class: 3
# Test 33 Prediction: 7 True Class: 7
# Test 34 Prediction: 2 True Class: 2
# Test 35 Prediction: 8 True Class: 8
# Test 36 Prediction: 0 True Class: 0
# Test 37 Prediction: 1 True Class: 1
# Test 38 Prediction: 2 True Class: 2
# Test 39 Prediction: 8 True Class: 8
# Test 40 Prediction: 9 True Class: 9
# Test 41 Prediction: 9 True Class: 9
# Test 42 Prediction: 7 True Class: 7
# Test 43 Prediction: 7 True Class: 7
# Test 44 Prediction: 7 True Class: 7
# Test 45 Prediction: 1 True Class: 1
